# %% [markdown]
# ## Imports

# %% [markdown]
# ## Load data

# %% [markdown]
# ## Load model

# %% [markdown]
# ## Extract activations

# %% [markdown]
# ## Clustering

# %% [markdown]
# ## Visualization
